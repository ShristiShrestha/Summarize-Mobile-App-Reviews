# %% [markdown]
# ## Imports

# %%
# %run lib.ipynb import *

# %%
import numpy as np, pandas as pd, json
import nltk
import pandas as pd
import matplotlib.pyplot as plt, re

# %% [markdown]
# ## Simple text preprocessing

# %%
def check_empty(arr):
    return [item for item in arr if len(item) > 0]
    
def preprocess(text, apps, should_ignore=False, should_stopwords_rm = False, should_lemma = False):
    cleaned_text = re.sub(r"'(\w)", "", text)
    # remove noise terms like html, nan, emojis
    cleaned_text = clean_text(cleaned_text.lower()) 
    cleaned_text = re.sub("-", " ", cleaned_text)
    tokens = nltk_tokenize(cleaned_text)
    tokens = remove_punctuation(tokens)
    tokens = remove_non_alphabetic(tokens)
    tokens = [item for item in tokens if len(item.strip()) > 0]
    return tokens

# %% [markdown]
# ## Entity Extraction from labelled summaries

# %%
def extract_annotated_labels(row, col="Denser_Summary", pos_label="pos", neg_label="neg", neu_label="neutral"):
    label_json = json.loads(row["label"])
    summary = row[col]
    pos_ents = []
    neg_ents = []
    neu_ents = []
    app = row["apps"]
    for item in label_json:
        ent_text = item["text"]
        ent_ann_labels = item["labels"]
        if pos_label in ent_ann_labels: # positive
            pos_ents.append(ent_text)
        elif neg_label in ent_ann_labels: # negative
            neg_ents.append(ent_text)
        elif neu_label in ent_ann_labels:
            neu_ents.append(ent_text)

    tokens = preprocess(summary, [])
    print(f"\n\n--------------{app}:--------------")
    print("positive ents: ", pos_ents)
    print("negative ents: ", neg_ents)
    print("neutral ents: ", neu_ents)
    
    total_tokens = len(tokens)
    row["#raw_tokens"] = len(nltk.word_tokenize(summary))
    row["#tokens"] = total_tokens
    row["pos_ents"] = ";".join(pos_ents)
    row["#pos_ents"] = len(pos_ents)
    row["neg_ents"] = ";".join(neg_ents)
    row["#neg_ents"] = len(neg_ents)
    row["neu_ents"] = ";".join(neu_ents)
    row["#neu_ents"] = len(neu_ents)
    total_ents = len(pos_ents) + len(neg_ents) + len(neu_ents)
    row["%pos_ents"] = float(len(pos_ents) / total_ents)
    row["%neg_ents"] = float(len(neg_ents) / total_ents)
    row["%neu_ents"] = float(len(neu_ents) / total_ents)
    row["%pos_neg_ents"] = float(len(pos_ents) / len(neg_ents))
    row["entity density"] = float(total_ents / total_tokens)
    row["#entities"] = total_ents
    return row

# %% [markdown]
# ## Compute entity quantity & entity density in CoD summaries

# %%
annotated_dir = "../data/summaries"
annotated_filenames = ["all_apps_codr.csv", 
                    "all_apps_cod.csv"
            ]

cols = ["apps", "Iteration turn", "Denser_Summary", "Missing_Entities", 
        "pos_ents", "neg_ents", "neu_ents", "#pos_ents", "#neg_ents", "#neu_ents",
       "#entities", "entity density", "#raw_tokens", "#tokens"]

cod_df_reviews = pd.read_csv(f"{annotated_dir}/{annotated_filenames[0]}") 
cod_df_reviews.rename(columns={"app": "apps"}, inplace=True)
cod_df_reviews = cod_df_reviews.apply(lambda row: extract_annotated_labels(row), axis=1)
cod_df_reviews = cod_df_reviews[cols]
print("CoD_R #rows: ", len(cod_df_reviews))

cod_df = pd.read_csv(f"{annotated_dir}/{annotated_filenames[1]}") 
cod_df.rename(columns={"app": "apps"}, inplace=True)
cod_df = cod_df.apply(lambda row: extract_annotated_labels(row, "Denser_Summary", "positive", "negative"), axis=1)
cod_df = cod_df[cols]
print("CoD #rows: ", len(cod_df))

# %%
# cod_df_reviews.to_csv(f"./data/summaries/{annotated_filenames[0]}", index=False, header=True)
# cod_df.to_csv(f"./data/summaries/{annotated_filenames[1]}", index=False, header=True)

# %%
cod_df.head(3)
# Out:
#      apps  Iteration turn                                     Denser_Summary  \
# 0  bumble               1  The app in question seems to have a variety of...
# 1  bumble               2  Users are encountering safety concerns and exp...
# 2  bumble               3  The app's user base reports persistent safety ...
#
#                                     Missing_Entities  \
# 0  safety concerns;photo verification issues;expe...
# 1        limited swipes;fake profiles;gender options
# 2  unresponsive matches;unclear guidelines;non-bi...
#
#                                          pos_ents  \
# 0  beneficial for creating meaningful connections
# 1               success in connecting with others
# 2
#
#                                             neg_ents neu_ents  #pos_ents  \
# 0  photo verification issues,;cost associated wit...                   1
# 1  safety concerns;expensive subscriptions;limite...                   1
# 2  safety concerns;expensive subscription model;f...                   0
#
#    #neg_ents  #neu_ents  #entities  entity density  #raw_tokens  #tokens
# 0          3          0          4        0.034188          132      117
# 1          6          0          7        0.064220          124      109
# 2          9          0          9        0.092784          111       97

# %%
cod_df_reviews.head(3)
# Out:
#      apps  Iteration turn                                     Denser_Summary  \
# 0  bumble               1  This application, known as Bumble, has been th...
# 1  bumble               2  Bumble's users report mixed experiences, highl...
# 2  bumble               3  Bumble's user experience is marred by an expen...
#
#                                     Missing_Entities pos_ents  \
# 0  expensive subscription;photo moderation;fake p...
# 1     gender options;limited swipes;customer service
# 2                  match algorithm;notification spam
#
#                                             neg_ents neu_ents  #pos_ents  \
# 0  cost associated with the subscription model;mo...                   0
# 1  costly subscription;photo moderation;limited n...                   0
# 2  subscription fee;photo moderation;restrictive ...                   0
#
#    #neg_ents  #neu_ents  #entities  entity density  #raw_tokens  #tokens
# 0          3          0          3        0.029703          114      101
# 1          5          0          5        0.060976           94       82
# 2          7          0          7        0.087500           91       80

# %%
view_cols = ["apps", "entity density", "#entities",  "#raw_tokens", "#tokens"]
cod_df[cod_df["apps"] == "bumble"][view_cols].head()
# Out:
#      apps  entity density  #entities  #raw_tokens  #tokens
# 0  bumble        0.034188          4          132      117
# 1  bumble        0.064220          7          124      109
# 2  bumble        0.092784          9          111       97
# 3  bumble        0.110000         11          112      100
# 4  bumble        0.122642         13          119      106

# %%
cod_df_reviews[cod_df_reviews["apps"] == "bumble"][view_cols].head()
# Out:
#      apps  entity density  #entities  #raw_tokens  #tokens
# 0  bumble        0.029703          3          114      101
# 1  bumble        0.060976          5           94       82
# 2  bumble        0.087500          7           91       80
# 3  bumble        0.104651          9           98       86
# 4  bumble        0.153846         12           91       78

# %%
apps = ["uber", "lyft", "tinder", "bumble", "robinhood", "acorn", "calm", "headspace"]

def format_ents_view(apps_cod_df, apps_codr_df, itr_col = "Iteration turn", ents_cols = "#entities"):
    apps_ents_stats = []

    for app in apps:
        app_ents_stats = [app]
        cod_df = apps_cod_df[apps_cod_df["apps"] == app]
        codr_df = apps_codr_df[apps_codr_df["apps"] == app]
        for itr in range(1, 6):
            df = cod_df[cod_df[itr_col] == itr]
            app_ents_stats.append(df[ents_cols].tolist()[0])
        for itr in range(1, 6):
            df = codr_df[codr_df[itr_col] == itr]
            app_ents_stats.append(df[ents_cols].tolist()[0])
        apps_ents_stats.append(app_ents_stats)
    
    
    cols = ["app"]
    cols.extend(["cod_"+str(i) for i in range(1, 6)])
    cols.extend(["cod_r_"+str(i) for i in range(1, 6)])
    apps_ents_stats_df = pd.DataFrame(apps_ents_stats, columns=cols)
    return apps_ents_stats_df

# %%
format_ents_view(cod_df, cod_df_reviews)
# Out:
#          app  cod_1  cod_2  cod_3  cod_4  cod_5  cod_r_1  cod_r_2  cod_r_3  \
# 0       uber      3      6      9     13     15        4        9       11
# 1       lyft      5      7     12     12     14        5       10       10
# 2     tinder      5      7      9      6      8        5        9       12
# 3     bumble      4      7      9     11     13        3        5        7
# 4  robinhood      3      4      5      4      2        6        8       10
# 5      acorn      5      6      5      8      6        9        9       10
# 6       calm      4      6      6      7      8        5        9       10
# 7  headspace      3      3      5      6      7        6        7        9
#
#    cod_r_4  cod_r_5
# 0       12       15
# 1       11       11
# 2       13       13
# 3        9       12
# 4       12       14
# 5       11       11
# 6       10        8
# 7       10       10

# %%
format_ents_view(cod_df, cod_df_reviews, itr_col = "Iteration turn", ents_cols = "entity density")
# Out:
#          app     cod_1     cod_2     cod_3     cod_4     cod_5   cod_r_1  \
# 0       uber  0.034091  0.077922  0.111111  0.164557  0.182927  0.037383
# 1       lyft  0.037037  0.063636  0.111111  0.108108  0.118644  0.049020
# 2     tinder  0.049020  0.093333  0.121622  0.082192  0.111111  0.056180
# 3     bumble  0.034188  0.064220  0.092784  0.110000  0.122642  0.029703
# 4  robinhood  0.031579  0.051282  0.066667  0.067797  0.037736  0.058824
# 5      acorn  0.052632  0.083333  0.068493  0.123077  0.089552  0.093750
# 6       calm  0.040816  0.064516  0.068182  0.076923  0.082474  0.050000
# 7  headspace  0.029412  0.033333  0.058824  0.071429  0.086420  0.058252
#
#     cod_r_2   cod_r_3   cod_r_4   cod_r_5
# 0  0.102273  0.146667  0.164384  0.192308
# 1  0.111111  0.123457  0.139241  0.137500
# 2  0.101124  0.131868  0.141304  0.156627
# 3  0.060976  0.087500  0.104651  0.153846
# 4  0.090909  0.111111  0.141176  0.155556
# 5  0.105882  0.129870  0.150685  0.148649
# 6  0.097826  0.119048  0.126582  0.093023
# 7  0.076087  0.105882  0.116279  0.113636

# %%
# compute mean for each cols:

for col in ["#entities", "entity density"]:
    print("....", col, ".....")
    df = format_ents_view(cod_df, cod_df_reviews, itr_col = "Iteration turn", ents_cols = col)
    cols = [item for item in df.columns if item != "app"]
    for c in cols:
        print(c, np.mean(df[c]))
# Out:
# .... #entities .....
# cod_1 4.0
# cod_2 5.75
# cod_3 7.5
# cod_4 8.375
# cod_5 9.125
# cod_r_1 5.375
# cod_r_2 8.25
# cod_r_3 9.875
# cod_r_4 11.0
# cod_r_5 11.75
# .... entity density .....
# cod_1 0.038596775713925204
# cod_2 0.06644710066987368
# cod_3 0.087349064242958
# cod_4 0.10051025406917566
# cod_5 0.1039381981703867
# cod_r_1 0.054138935948423755
# cod_r_2 0.09327344137176027
# cod_r_3 0.11942535020353648
# cod_r_4 0.13553779111665915
# cod_r_5 0.14389302197905798

# %% [markdown]
# ## Compute entity quantity & entity density of baseline summaries

# %%
annotated_dir = "../data/summaries"

baselines = {}
types = ["vanilla", "tfidf"]

for type in types:
    df = pd.read_csv(f"{annotated_dir}/all_apps_{type}_old.csv")
    df = df.apply(lambda row: extract_annotated_labels(row, "summary", "positive", "negative"), axis=1)
    baselines[type] = df
    print("mean: ", np.mean(df["#entities"]), np.mean(df["entity density"]))

# %%
df = baselines["vanilla"]
print("mean: ", np.mean(df["#entities"]), np.mean(df["entity density"]))
df[view_cols]
# Out:
# mean:  9.5 0.08583842254645581
#         apps  entity density  \
# 0       Uber        0.084746
# 1       Lyft        0.081967
# 2     Tinder        0.084906
# 3     Bumble        0.117117
# 4  Robinhood        0.077586
# 5      Acorn        0.093750
# 6       Calm        0.068966
# 7  Headspace        0.077670
#
#                                              summary  \
# 0  Users report mixed experiences with Uber's app...
# 1  The Lyft app receives mixed reviews. Some user...
# 2  Many users express frustration with Tinder, ci...
# 3  The Bumble app receives mixed reviews. Some us...
# 4  Users have mixed feelings about Robinhood. Som...
# 5  Users appreciate Acorn's app for its easy savi...
# 6  The Calm app, designed to aid with anxiety and...
# 7  Headspace app receives mixed reviews. Many use...
#
#                                             pos_ents  \
# 0  convenience of the service;payment options;saf...
# 1  positive interactions with drivers;reliability...
# 2           success in meeting people through Tinder
# 3  unique approach, where women initiate conversa...
# 4  user-friendly platform;educational;instant dep...
# 5          automatic round-ups;recurring investments
# 6  helpful for relaxation, meditation, and sleep;...
# 7  benefits for meditation and sleep;sleepcasts;v...
#
#                                             neg_ents  \
# 0  app's glitches;customer service;safety concern...
# 1  dynamic pricing;app's navigation;customer serv...
# 2  banned without explanation;fake profiles;bots;...
# 3  24-hour message limit;limited swipes;fake prof...
# 4  customer service;technical issues during high-...
# 5  customer service;account verification;withdraw...
# 6  subscription cost;previously free features now...
# 7  requiring payment for most features;substantia...
#
#                                             neu_ents
# 0
# 1
# 2
# 3
# 4
# 5
# 6  call for more diversity in authors for sleep s...
# 7

# %%
df = baselines["tfidf"]
print("mean: ", np.mean(df["#entities"]), np.mean(df["entity density"]))
df[view_cols]
# Out:
# mean:  6.25 0.051172816529636164
#         apps  entity density  \
# 0       Uber        0.045455
# 1       Lyft        0.035088
# 2     Tinder        0.071429
# 3     Bumble        0.080645
# 4  Robinhood        0.034483
# 5      Acorn        0.050000
# 6       Calm        0.049180
# 7  Headspace        0.043103
#
#                                              summary  \
# 0  Uber drivers are getting lazy to accepts rides...
# 1  20 minute waits for a 5 minute ride, then driv...
# 2  They made it so when you get banned, you can’t...
# 3  You don’t get to see all your likes, you only ...
# 4  They made it easy to trade stocks, buy stocks....
# 5  Now, they are taking money out of my account e...
# 6  I also love the sleep meditations and stories ...
# 7  I understand they need to make money off the a...
#
#                                             pos_ents  \
# 0
# 1
# 2
# 3
# 4  easy to trade stocks;make money on crypto;layo...
# 5       beginner investors and long term investments
# 6   sleep meditations and stories;dailies;soundscape
# 7
#
#                                             neg_ents  \
# 0  accepts rides;driver was fantastic very person...
# 1  drivers cancel 10 minutes into waiting;prices ...
# 2  banned;same 12 matches for over a month;countl...
# 3  see all your likes,;more results;more swipes;t...
# 4                                     lost money and
# 5  money out of my account;verify with the email ...
# 6     unwanted stories;daily check-in font;playlists
# 7  guided meditation;scripts for the meditations;...
#
#                                neu_ents
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7  30 min - 45 min meditations;practice

# %%
view_cols = ["apps", "entity density", "summary", "pos_ents", "neg_ents", "neu_ents", "#entities", "entity density", "#raw_tokens", "#tokens"]

baselines["tfidf"][view_cols].to_csv(f"./data/summaries/all_apps_tfidf.csv", index=False, header=True)
baselines["vanilla"][view_cols].to_csv(f"./data/summaries/all_apps_vanilla.csv", index=False, header=True)

# %% [markdown]
# ## Run statistical analysis on entity count and density
#
# - use multiple paired t-test to determine the significance of difference in statistic of two groups.
# - use one way ANOVA to compare the average statistics of more than two groups.

# %% [markdown]
# ### Normality test
#
# - Null hypothesis H0: the distribution is normal.
# - Alternate hypothesis H1: the distribution is not normal.
# - Significance level = 0.01 and 0.05 which suggest confidence of 99% and 95% repectively.
# - If the observed p-value from the Shapiro-Wilk test is above the significance level, we fail to reject the null hypothesis. In other words, we found no sufficient evidence to claim that the distribution of the values is not normal.

# %%
from scipy.stats import shapiro

def shapiro_test(data):
    stat, p_value = shapiro(data)
    if p_value > 0.05:
        print("..***failed to reject H0***..")
    return stat, p_value

# %%
for _column in ["#entities", "entity density"]:
    print("\n\n....col" , _column, ".....")
    vanilla = baselines["vanilla"][_column]
    print("vanilla: ", shapiro_test(vanilla))

    for itr in range(1, 6):
        print("\niteration: ", itr)
       
        codr = cod_df_reviews[cod_df_reviews["Iteration turn"] == itr][_column]
        cod = cod_df[cod_df["Iteration turn"] == itr][_column]

        print("cod: ", shapiro_test(cod))
        print("codr: ", shapiro_test(codr))
# Out:
# ....col #entities .....
# vanilla:  (0.8162244558334351, 0.04258103668689728)
#
# iteration:  1
# cod:  (0.8015025854110718, 0.029704909771680832)
# ..***failed to reject H0***..
# codr:  (0.9004141092300415, 0.29144734144210815)
#
# iteration:  2
# cod:  (0.8104381561279297, 0.036982372403144836)
# ..***failed to reject H0***..
# codr:  (0.8395451307296753, 0.07451588660478592)
#
# iteration:  3
# ..***failed to reject H0***..
# cod:  (0.8454927206039429, 0.0857318639755249)
# ..***failed to reject H0***..
# codr:  (0.8995161652565002, 0.2860732674598694)
#
# iteration:  4
# ..***failed to reject H0***..
# cod:  (0.9270010590553284, 0.4891917109489441)
# ..***failed to reject H0***..
# codr:  (0.9650728702545166, 0.8567925095558167)
#
# iteration:  5
# ..***failed to reject H0***..
# cod:  (0.930121660232544, 0.5171833038330078)
# ..***failed to reject H0***..
# codr:  (0.9542165398597717, 0.75356125831604)
#
#
# ....col entity density .....
# ..***failed to reject H0***..
# vanilla:  (0.8612016439437866, 0.12342841923236847)
#
# iteration:  1
# ..***failed to reject H0***..
# cod:  (0.898576557636261, 0.28053751587867737)
# ..***failed to reject H0***..
# codr:  (0.8906373977661133, 0.23724400997161865)
#
# iteration:  2
# ..***failed to reject H0***..
# cod:  (0.9654775261878967, 0.8603523373603821)
# ..***failed to reject H0***..
# codr:  (0.8861083984375, 0.21520771086215973)
#
# iteration:  3
# ..***failed to reject H0***..
# cod:  (0.8641997575759888, 0.1321754902601242)
# ..***failed to reject H0***..
# codr:  (0.9856573343276978, 0.9853461980819702)
#
# iteration:  4
# ..***failed to reject H0***..
# cod:  (0.891612708568573, 0.24223580956459045)
# ..***failed to reject H0***..
# codr:  (0.9708886742591858, 0.9048891663551331)
#
# iteration:  5
# ..***failed to reject H0***..
# cod:  (0.9446483254432678, 0.657311201095581)
# ..***failed to reject H0***..
# codr:  (0.9633861184120178, 0.8416681885719299)

# %% [markdown]
# ### Paired t-test
# ---
#
# - The sampled source reviews used for summarization is the same for all methods: CoDr, CoD, and Vanilla.
# - In a paired t-test, we compute difference between two set of observed data, and assess whether the average difference is significant or not.
# - First, we perform Shapiro-Wilk's test on the set of difference values.
#     - Null hypothesis H0: the distribution is normal.
#     - Alternate hypothesis H1: the distribution is not normal.
#     - Significance level = 0.01 and 0.05 which suggest confidence of 99% and 95% repectively.
#     - If the observed p-value from the Shapiro-Wilk test is above the significance level, we fail to reject the null hypothesis. In other words, we found no sufficient evidence to claim that the distribution of the difference values is not normal.
# - Use paired t-test on the set of difference values.
#     - Null hypothesis H0: the change reflected by the average difference is significant.
#     - Alternate hypothesis H1: the change reflected by the average difference is not significant.
#     - Significance level = 0.01 and 0.05 which suggest confidence of 99% and 95% repectively.
#     - If the observed p-value from the Shapiro-Wilk test is below the significance level, we reject the null hypothesis. In other words, the observed change in values betwene the two groups is significant.

# %%
from scipy.stats import f_oneway, ttest_rel

def paired_ttest(col1, col2):
    statistic, p_value = ttest_rel(col1, col2)
    if p_value < 0.05:
        print("***significant***")
    return statistic, p_value

# %%
# let's run paired t-test for cod_5, codr_5 and vanilla. 
# Since, this is a paired test (only two groups) we will use combinations of pairs. 

for _column in ["#entities", "entity density"]:
    print("\n\n....col" , _column, ".....")
    vanilla = baselines["vanilla"][_column]
    tfidf = baselines["tfidf"][_column]
    
    for itr in range(1, 6):
        print("\niteration: ", itr)
        
        codr = cod_df_reviews[cod_df_reviews["Iteration turn"] == itr][_column]
        print("vanilla vs codr: ", paired_ttest(vanilla, codr))
        
        cod = cod_df[cod_df["Iteration turn"] == itr][_column]
        print("vanilla vs cod", paired_ttest(vanilla, cod))

        print("tfidf vs codr", paired_ttest(tfidf, codr))
        print("tfidf vs cod", paired_ttest(tfidf, cod))

        for itr_2 in range(1, 6):
            cod_2 = cod_df[cod_df["Iteration turn"] == itr_2][_column]
            print(f"cod[{str(itr_2)}] vs codr[{str(itr)}]: ", paired_ttest(codr, cod_2))
# Out:
# ....col #entities .....
#
# iteration:  1
# ***significant***
# vanilla vs codr:  (8.602889557460568, 5.7153950148406615e-05)
# ***significant***
# vanilla vs cod (11.0, 1.1376151194592588e-05)
# tfidf vs codr (1.5071573172061195, 0.1754994493585011)
# ***significant***
# tfidf vs cod (2.5528888301902897, 0.03794328796316367)
# cod[1] vs codr[1]:  (2.2, 0.06373101530263678)
# cod[2] vs codr[1]:  (-0.39735970711951313, 0.7029400234562209)
# cod[3] vs codr[1]:  (-1.5240136747505373, 0.1713281412298464)
# cod[4] vs codr[1]:  (-1.9540168418367887, 0.09162379533890302)
# cod[5] vs codr[1]:  (-1.8364615450436153, 0.10890866499940696)
#
# iteration:  2
# vanilla vs codr:  (1.4883513944689681, 0.18026237269037185)
# ***significant***
# vanilla vs cod (5.16671222870379, 0.0012997914254367544)
# tfidf vs codr (-2.0, 0.08561932856297597)
# tfidf vs cod (0.4605661864718383, 0.6590761036459647)
# ***significant***
# cod[1] vs codr[2]:  (8.078246376295356, 8.56523155312282e-05)
# ***significant***
# cod[2] vs codr[2]:  (3.668996928526714, 0.007974815912587956)
# cod[3] vs codr[2]:  (0.7673233000039631, 0.4679759804057353)
# cod[4] vs codr[2]:  (-0.10035906758257156, 0.9228731635807381)
# cod[5] vs codr[2]:  (-0.522787502632156, 0.6172557503288335)
#
# iteration:  3
# vanilla vs codr:  (-0.4685212856658182, 0.6536513528934699)
# vanilla vs cod (1.560378995210988, 0.16263688311923707)
# ***significant***
# tfidf vs codr (-3.629052544585798, 0.008408418821338328)
# tfidf vs cod (-0.8349917097663223, 0.43129419064608554)
# ***significant***
# cod[1] vs codr[3]:  (10.702370800002248, 1.3652708989781144e-05)
# ***significant***
# cod[2] vs codr[3]:  (5.954478478715695, 0.0005675115338626768)
# cod[3] vs codr[3]:  (2.336211328054561, 0.052134933862171225)
# cod[4] vs codr[3]:  (1.1224972160321824, 0.2986718763094996)
# cod[5] vs codr[3]:  (0.4336585079213105, 0.6775871436017953)
#
# iteration:  4
# vanilla vs codr:  (-1.984313483298443, 0.0876228290414024)
# vanilla vs cod (0.7995207132483751, 0.45026282465586576)
# ***significant***
# tfidf vs codr (-5.389431974846167, 0.001019983665146904)
# tfidf vs cod (-1.4007757307701494, 0.20401863043400228)
# ***significant***
# cod[1] vs codr[4]:  (13.095800853708795, 3.530011282993485e-06)
# ***significant***
# cod[2] vs codr[4]:  (7.780065023166959, 0.0001088597032482944)
# ***significant***
# cod[3] vs codr[4]:  (3.564225540521209, 0.00916745229433617)
# cod[4] vs codr[4]:  (1.9855802012591144, 0.08745934260808005)
# cod[5] vs codr[4]:  (1.0797236261230418, 0.31605687183335573)
#
# iteration:  5
# vanilla vs codr:  (-2.005459744616267, 0.08493265380754311)
# vanilla vs cod (0.19849338720843682, 0.8483008699680887)
# ***significant***
# tfidf vs codr (-5.695489135379688, 0.0007387882976266487)
# tfidf vs cod (-1.3805128571809815, 0.20989919902007353)
# ***significant***
# cod[1] vs codr[5]:  (8.079647378096768, 8.555736561467588e-05)
# ***significant***
# cod[2] vs codr[5]:  (6.163816106328043, 0.0004612585736744562)
# ***significant***
# cod[3] vs codr[5]:  (3.7747315309623177, 0.006939877143229542)
# ***significant***
# cod[4] vs codr[5]:  (2.488717998787109, 0.04167471235395339)
# cod[5] vs codr[5]:  (1.452044673878789, 0.18979089587740422)
#
#
# ....col entity density .....
#
# iteration:  1
# ***significant***
# vanilla vs codr:  (8.831362936982117, 4.823355238276264e-05)
# ***significant***
# vanilla vs cod (10.432722518584134, 1.617043503421216e-05)
# tfidf vs codr (-0.5856818108929773, 0.5764763460458513)
# tfidf vs cod (2.026336924632131, 0.08235671336207945)
# ***significant***
# cod[1] vs codr[1]:  (2.869850486029047, 0.023997136533063245)
# cod[2] vs codr[1]:  (-1.4188600247001637, 0.1988946335480504)
# ***significant***
# cod[3] vs codr[1]:  (-2.515591534256205, 0.040067951270809296)
# ***significant***
# cod[4] vs codr[1]:  (-3.2464265451933487, 0.014126909768231728)
# ***significant***
# cod[5] vs codr[1]:  (-2.6249057004647374, 0.03416464808955703)
#
# iteration:  2
# vanilla vs codr:  (-0.927138173115775, 0.3847071584237804)
# vanilla vs cod (2.3199702123447223, 0.053396796648734125)
# ***significant***
# tfidf vs codr (-5.269126246273988, 0.0011617269332474824)
# tfidf vs cod (-1.6639368195673474, 0.14007275401384048)
# ***significant***
# cod[1] vs codr[2]:  (10.796550318675733, 1.2880647363567009e-05)
# ***significant***
# cod[2] vs codr[2]:  (4.302565987427834, 0.003555384170587032)
# cod[3] vs codr[2]:  (0.6689912699054072, 0.5249426059206009)
# cod[4] vs codr[2]:  (-0.6245143802661726, 0.5520929768761588)
# cod[5] vs codr[2]:  (-0.700205780943412, 0.5063966824208161)
#
# iteration:  3
# ***significant***
# vanilla vs codr:  (-3.8229121776538055, 0.006517537179765909)
# vanilla vs cod (-0.12248146929886407, 0.9059599831887879)
# ***significant***
# tfidf vs codr (-7.977529725162277, 9.280063070260175e-05)
# ***significant***
# tfidf vs cod (-2.837481806321432, 0.025135149715168545)
# ***significant***
# cod[1] vs codr[3]:  (14.098338402634795, 2.141992273641469e-06)
# ***significant***
# cod[2] vs codr[3]:  (9.19288639883886, 3.715372824919592e-05)
# ***significant***
# cod[3] vs codr[3]:  (3.862171030437103, 0.006194073594897185)
# cod[4] vs codr[3]:  (1.899801783328958, 0.09923494048346936)
# cod[5] vs codr[3]:  (1.1700744821157918, 0.28026154846451995)
#
# iteration:  4
# ***significant***
# vanilla vs codr:  (-5.702368313714147, 0.0007335522957341366)
# vanilla vs cod (-1.1086982791226816, 0.30419329896740516)
# ***significant***
# tfidf vs codr (-11.514338016212623, 8.385862168370351e-06)
# ***significant***
# tfidf vs cod (-3.999251323747654, 0.005194861947221391)
# ***significant***
# cod[1] vs codr[4]:  (15.291681706005063, 1.2323186822466097e-06)
# ***significant***
# cod[2] vs codr[4]:  (10.80731120091369, 1.2795631422810253e-05)
# ***significant***
# cod[3] vs codr[4]:  (5.317391479848025, 0.0011023824323049287)
# ***significant***
# cod[4] vs codr[4]:  (3.6001350035646653, 0.008738245854648512)
# cod[5] vs codr[4]:  (2.2255695055047084, 0.061370777634936445)
#
# iteration:  5
# ***significant***
# vanilla vs codr:  (-4.539799105142565, 0.0026683342554579526)
# vanilla vs cod (-1.0270183295484077, 0.33858629507207605)
# ***significant***
# tfidf vs codr (-8.758632385021073, 5.088988888415681e-05)
# ***significant***
# tfidf vs cod (-2.9511136597316683, 0.021373035543247387)
# ***significant***
# cod[1] vs codr[5]:  (9.618347206766833, 2.7634249347539415e-05)
# ***significant***
# cod[2] vs codr[5]:  (8.16858652632023, 7.976613941426101e-05)
# ***significant***
# cod[3] vs codr[5]:  (6.035061694749779, 0.0005236643672247985)
# ***significant***
# cod[4] vs codr[5]:  (4.625611587310301, 0.0024101288656686436)
# ***significant***
# cod[5] vs codr[5]:  (2.9741698203090046, 0.020685084252979102)
